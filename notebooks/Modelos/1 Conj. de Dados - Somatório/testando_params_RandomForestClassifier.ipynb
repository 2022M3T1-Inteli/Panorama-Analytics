# %% [markdown]
# #Importando as bibliotecas e baixando o csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit,cross_val_score,GridSearchCV,train_test_split
from sklearn.ensemble import RandomForestClassifier
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials
import warnings
warnings.filterwarnings('ignore')

# %%
# Autenticação para acesso aos dados
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Download dos dados para esta máquina virtual
downloaded = drive.CreateFile({'id': '1YsLk4m04XeO2CKqOMKeug5dvZXhlwGQU'})
downloaded.GetContentFile('data.csv')

# %%
# Carregando os dados baixados no dataframe 
df = pd.read_csv('data.csv')

# %% [markdown]
# #Separando a coluna resposta e as variáveis de treino

# %%
# separando entre x e y
x = df.drop(columns=["ind_engaj", "Unnamed: 0", "num_cpf_hash"]).copy()
y = df.drop(columns=["Unnamed: 0", "num_cpf_hash", "vlr_credito", "vlr_saldo", "num_atend_atrs", "vlr_score", "num_produtos", "qtd_oper", "qtd_reclm", "qtd_restr", "cod_rating", "ind_atrito", "num_atend"]).copy()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=11)

# %% [markdown]
# #Primeiro teste de parâmetros

# %%
params = {
    "n_estimators" : [80, 90, 100],
    "criterion" : ["gini", "entropy", "log_loss"],
    #"max_depth" : [1, 2, 3, None],
    "min_samples_split": [1, 2, 3],
    "min_samples_leaf": [1, 2, 3],
    "bootstrap" : [True],
    "n_jobs"  : [-1],
    "random_state": [42]
}

grid_search = GridSearchCV(RandomForestClassifier(),params)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [1, 2, 3],
#                          'n_estimators': [80, 90, 100], 'n_jobs': [-1],
#                          'random_state': [42]})

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 80,
#  'n_jobs': -1,
#  'random_state': 42}

# %% [markdown]
# #Segundo teste de parâmetros

# %%
params_2 = {
    "n_estimators" : [70, 75, 80],
    #"max_depth" : [1, 2, 3, None],
    "min_samples_split": [1, 2, 3],
    "min_samples_leaf": [3, 4, 5],
    "bootstrap" : [True],
    "n_jobs"  : [-1],
    "random_state": [42]
}

grid_search_2 = GridSearchCV(RandomForestClassifier(),params_2)

# %%
grid_search_2.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True], 'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [1, 2, 3],
#                          'n_estimators': [70, 75, 80], 'n_jobs': [-1],
#                          'random_state': [42]})

# %%
grid_search_2.best_params_
# Out:
# {'bootstrap': True,
#  'min_samples_leaf': 5,
#  'min_samples_split': 2,
#  'n_estimators': 80,
#  'n_jobs': -1,
#  'random_state': 42}

# %% [markdown]
# #Terceiro teste de parâmetros

# %%
params_3 = {
    "n_estimators" : [80],
    #"max_depth" : [1, 2, 3, None],
    "min_samples_split": [2],
    "min_samples_leaf": [5, 6, 7],
    "bootstrap" : [True],
    "n_jobs"  : [-1],
    "random_state": [42]
}

grid_search_3 = GridSearchCV(RandomForestClassifier(),params_3)

# %%
grid_search_3.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True], 'min_samples_leaf': [5, 6, 7],
#                          'min_samples_split': [2], 'n_estimators': [80],
#                          'n_jobs': [-1], 'random_state': [42]})

# %%
grid_search_3.best_params_
# Out:
# {'bootstrap': True,
#  'min_samples_leaf': 7,
#  'min_samples_split': 2,
#  'n_estimators': 80,
#  'n_jobs': -1,
#  'random_state': 42}

# %% [markdown]
# #Quarto teste de parâmetros

# %%
params_4 = {
    "n_estimators" : [80],
    #"max_depth" : [1, 2, 3, None],
    "min_samples_split": [2],
    "min_samples_leaf": [7, 8, 9],
    "bootstrap" : [True],
    "n_jobs"  : [-1],
    "random_state": [42]
}

grid_search_4 = GridSearchCV(RandomForestClassifier(),params_4)

# %%
grid_search_4.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True], 'min_samples_leaf': [7, 8, 9],
#                          'min_samples_split': [2], 'n_estimators': [80],
#                          'n_jobs': [-1], 'random_state': [42]})

# %%
grid_search_4.best_params_
# Out:
# {'bootstrap': True,
#  'min_samples_leaf': 8,
#  'min_samples_split': 2,
#  'n_estimators': 80,
#  'n_jobs': -1,
#  'random_state': 42}

# %% [markdown]
# #Quinto teste de parâmetros

# %%
params_5 = {
    "n_estimators" : [80],
    "max_depth" : [1, 2, 3, None],
    "min_samples_split": [2],
    "min_samples_leaf": [8],
    "bootstrap" : [True],
    "n_jobs"  : [-1],
    "random_state": [42]
}

grid_search_5 = GridSearchCV(RandomForestClassifier(),params_5)

# %%
grid_search_5.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True], 'max_depth': [1, 2, 3, None],
#                          'min_samples_leaf': [8], 'min_samples_split': [2],
#                          'n_estimators': [80], 'n_jobs': [-1],
#                          'random_state': [42]})

# %%
grid_search_5.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': None,
#  'min_samples_leaf': 8,
#  'min_samples_split': 2,
#  'n_estimators': 80,
#  'n_jobs': -1,
#  'random_state': 42}

# %% [markdown]
# #Testando o modelo com o cross validation

# %%
teste_modelo = cross_val_score(RandomForestClassifier(n_estimators=80, min_samples_leaf=8, min_samples_split=2, n_jobs= -1, random_state=42), x, y, scoring="f1", cv=6)

# %%
teste_modelo.mean()
# Out:
# 0.8276862158162714

# %%
teste_modelo.std()
# Out:
# 0.001069762109392465

# %% [markdown]
# #Testando o modelo com o x_test e y_test

# %%
from sklearn.metrics import f1_score

# %%
unico_modelo = RandomForestClassifier(n_estimators=80, min_samples_leaf=8, min_samples_split=2, n_jobs= -1, random_state=42)

# %%
unico_modelo.fit(x_train, y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=8, n_estimators=80, n_jobs=-1,
#                        random_state=42)

# %%
y_predict_teste = unico_modelo.predict(x_test)

# %%
f1_score(y_test, y_predict_teste)
# Out:
# 0.8282102575015962
